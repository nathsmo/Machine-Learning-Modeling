# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
im = cv.imread('lenna.png', cv.IMREAD_COLOR)

# %%
im.shape
# Out:
# (220, 220, 3)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
img = cv.cvtColor(im, cv.COLOR_BGR2RGB)

# %%
fig = plt.figure(figsize=(10,10,))
plt.imshow(img)
