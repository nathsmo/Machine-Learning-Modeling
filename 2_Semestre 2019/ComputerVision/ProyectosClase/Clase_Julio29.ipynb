# %% [markdown]
# # Clase 29 de Julio 2019
# ## Nathalia Morales
# ### * Split RBG: Recibe imagen y va a mostrar con su titulo original  y separa RGB contra R - G - B

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
from matplotlib.pyplot import figure

# %%
img = cv.imread("baboon.png", cv.IMREAD_COLOR)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
def split_rgb(img, filename=None):
    
    fig = plt.figure(figsize=(10,10))
    ax1 = fig.add_subplot(221)
    ax1.imshow(img)
    ax1.set_title('RGB')
    plt.axis('off')
    ax2 = fig.add_subplot(222)
    ax2.imshow(img[:,:,0], cmap='gray', vmin=0, vmax=255)
    ax2.set_title('R')
    plt.axis('off')
    ax3 = fig.add_subplot(223)
    ax3.imshow(img[:,:,1], cmap='gray', vmin=0, vmax=255)
    ax3.set_title('G')
    plt.axis('off')
    ax4 = fig.add_subplot(224)
    ax4.imshow(img[:,:,2], cmap='gray', vmin=0, vmax=255)
    ax4.set_title('B')
    plt.axis('off')
    if filename != None:
        f.savefig(filename)
    plt.show()

split_rgb(img)

# %%
def hist(img, filename=None):
    
    fig = plt.figure(figsize=(30,10))
    ax1 = fig.add_subplot(111)
    colors = ['r','g','b']
    for i, color in enumerate(colors):
        histr = cv.calcHist([img],[i],None,[256],[0,256])
        ax1.plot(histr, c=color)
        
    plt.show

hist(img)
